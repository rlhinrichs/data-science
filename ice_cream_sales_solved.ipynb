# %%
# Rebecca Hinrichs
# DATA 3401
# 1 Feb 2022

# %%
# Lab 3A

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
temp = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
sales = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]

# %%
# Tell matplotlib to create a scatter plot based upon the above data
x = temp
y = sales
fig = plt.figure()
plt.scatter(x,y, color="darkred")

# %%
# Set the upper and lower limits of our y axis
fig, ax = plt.subplots()
ax.set_ylim([150,550])
plt.scatter(x,y, color="darkred")

# %%
# Set the upper and lower limits of our x axis
ax.set_xlim([12,25])
plt.scatter(x,y, color="darkred")

# %%
# Create a title, x label, and y label for our chart
fig, ax = plt.subplots()
ax.set_title('Ice Cream Sales')
ax.set_xlabel('temp')
ax.set_ylabel('sales')
plt.scatter(x,y, color="darkred")

# %%
# Save an image of the chart and print to screen
# NOTE: If your plot shrinks after saving an image,
# update matplotlib or simply run the above cells again.

# %%
scoop_price = [2.99,101.35,4.56,200.15,12.58,65.00,54.87,28.95,10,11,3.25,90.5]
x = temp
y = scoop_price
fig = plt.figure()
plt.scatter(x,y, s=scoop_price, color="darkred")
